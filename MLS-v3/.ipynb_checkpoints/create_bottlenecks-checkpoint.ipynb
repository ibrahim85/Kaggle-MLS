# %%
import os
import re
import time
import librosa
import numpy as np
from scipy import io
from tqdm import tqdm
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
INPUT_DIRS = [
    '/datasets/kaggle/mls/train_1',
    '/datasets/kaggle/mls/train_2',
    '/datasets/kaggle/mls/train_3',
    '/datasets/kaggle/mls/test_1',
    '/datasets/kaggle/mls/test_2',
    '/datasets/kaggle/mls/test_3'
]

OUTPUT_DIRS = {
    'bottlenecks': 'out/bottlenecks'
}

SAMPLING_RATE = 400
N_CHANNELS = 16
N_SAMPLES = 240000

N_FFT = 512
N_MELS = 96
DESIRED_MSG_W = 1366
HOP_LEN = 1 + int(N_SAMPLES / (DESIRED_MSG_W - 1))

TOP_DB = 80.

print 'Params:\n'
print 'DESIRED_MSG_W', DESIRED_MSG_W
print 'HOP_LEN', HOP_LEN
# Out:
# Params:
#
# DESIRED_MSG_W 1366
# HOP_LEN 176

# %%
# make sure output dirs exist
for v in OUTPUT_DIRS.values(): 
    if not os.path.isdir(v): 
        os.makedirs(v)

# %%
# list files in directories
def list_files(src_dirs):

    if not list == type(src_dirs): src_dirs = [src_dirs]
    
    f = []
    
    for d in src_dirs:
        df = []
        for (dirpath, dirnames, filenames) in os.walk(d):
            filenames = [dirpath + '/' + x for x in filenames]
            df.extend(filenames)
        f.extend(df)
    
    return f

# %%
def read_mat(f):
    mat = io.loadmat(f)
    
    sampling_rate = int(mat['dataStruct'][0, 0][1][0, 0])
    n_samples = int(mat['dataStruct'][0, 0][2][0, 0])
    ch_indexes = np.int8(mat['dataStruct'][0, 0][3][0])
    
    # make sure all files have the same format
    assert(sampling_rate == SAMPLING_RATE)
    assert(n_samples == N_SAMPLES)
    assert(len(ch_indexes) == N_CHANNELS)
    
    data = mat['dataStruct'][0, 0][0].T
    
    waves = np.zeros([len(ch_indexes), n_samples], dtype=np.float32)
    
    for i in range(len(ch_indexes)):
        waves[i] = data[ch_indexes[i] - 1]  
        
    return waves

# %%
# compute msg for a wave
def compute_msg(wave, \
                sr=SAMPLING_RATE, hop_length=HOP_LEN, \
                n_fft=N_FFT, n_mels=N_MELS, \
                desired_msg_w=DESIRED_MSG_W):
    
    # pad wave if neccessary to get the desired msg width
    desired_wave_len = hop_length * (desired_msg_w - 1)
    if desired_wave_len > len(wave):
        wave = np.pad(wave, (0, desired_wave_len - len(wave)), \
                      'constant', constant_values=(0))
    
    msg = librosa.feature.melspectrogram(y=wave, sr=sr, hop_length=hop_length, n_fft=n_fft, n_mels=n_mels)
    msg = librosa.logamplitude(msg ** 2, ref_power=1., top_db=TOP_DB)
    
    return msg

# %%
# load music tagger crnn trained on million songs dataset
from keras.applications.music_tagger_crnn import MusicTaggerCRNN
music_tagger_crnn = MusicTaggerCRNN(weights='msd', include_top=False)
# Out:
# Using TensorFlow backend.

# %%
# process waveforms
for f in tqdm(list_files(INPUT_DIRS)):

    fid = re.findall(r'([\d_]+)\.mat$', f)[0]
    bns_f = OUTPUT_DIRS['bottlenecks'] + '/' + fid + '.npy'
    
    if not os.path.isfile(bns_f):

        waves = read_mat(f)
        msgs = np.zeros([N_CHANNELS, N_MELS, DESIRED_MSG_W])

        for i in range(waves.shape[0]):
            msgs[i] = compute_msg(waves[i])

        bns = music_tagger_crnn.predict(msgs.reshape(msgs.shape + (1,)))
        np.save(bns_f, bns)
# Out:
#  72%|███████▏  | 8755/12168 [2:19:23<52:59,  1.07it/s]
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-8-b8564f09e6b7> in <module>()
#      10
#      11     bns_f = OUTPUT_DIRS['bottlenecks'] + '/' + fid + '.npy'
# ---> 12     bns = music_tagger_crnn.predict(msgs.reshape(msgs.shape + (1,)))
#      13     np.save(bns_f, bns)
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.1.0-py2.7.egg/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1190         f = self.predict_function
#    1191         return self._predict_loop(f, ins,
# -> 1192                                   batch_size=batch_size, verbose=verbose)
#    1193
#    1194     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.1.0-py2.7.egg/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#     889                 ins_batch = slice_X(ins, batch_ids)
#     890
# --> 891             batch_outs = f(ins_batch)
#     892             if type(batch_outs) != list:
#     893                 batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/dist-packages/Keras-1.1.0-py2.7.egg/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    1038             feed_dict[tensor] = value
#    1039         session = get_session()
# -> 1040         updated = session.run(self.outputs + [self.updates_op], feed_dict=feed_dict)
#    1041         return updated[:len(self.outputs)]
#    1042
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     380     try:
#     381       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 382                          run_metadata_ptr)
#     383       if run_metadata:
#     384         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     653     movers = self._update_with_movers(feed_dict_string, feed_map)
#     654     results = self._do_run(handle, target_list, unique_fetches,
# --> 655                            feed_dict_string, options, run_metadata)
#     656
#     657     # User may have fetched the same tensor multiple times, but we
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     721     if handle is None:
#     722       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 723                            target_list, options, run_metadata)
#     724     else:
#     725       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     728   def _do_call(self, fn, *args):
#     729     try:
# --> 730       return fn(*args)
#     731     except errors.OpError as e:
#     732       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     710         return tf_session.TF_Run(session, options,
#     711                                  feed_dict, fetch_list, target_list,
# --> 712                                  status, run_metadata)
#     713
#     714     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
########################################

# %%
plt.figure(figsize=(13,4))
plt.plot(bns.flatten()[:200])

# %%
waves = read_mat('/datasets/kaggle/mls/b/train_1/1_45_1.mat')

# %%
msg = compute_msg(waves[0])

# %%
print msg.shape
plt.figure(figsize=(10, 4))
plt.imshow(np.flipud(msg), aspect=4)
plt.savefig('msg.png')
# Out:
# (96, 1366)

# %%
print msg.shape
plt.figure(figsize=(10, 4))
plt.imshow(np.flipud(msg), aspect=4)
plt.savefig('msg.png')
# Out:
# (96, 1366)

# %%
print msg.shape
plt.figure(figsize=(10, 4))
plt.imshow(np.flipud(msg), aspect=4)
plt.savefig('msg.png')
# Out:
# (96, 1366)

# %%
melgram = msg.reshape(msg.shape + (1,))
melgrams = np.expand_dims(melgram, axis=0)

preds = music_tagger_crnn.predict(melgrams)
# print('Predicted:')
# print(decode_predictions(preds))
# print: ('Predicted:', [[('rock', 0.097071797), ('pop', 0.042456303), ('alternative', 0.032439161), ('indie', 0.024491295), ('female vocalists', 0.016455274)]])
preds.shape
# Out:
# (1, 32)

# %%
plt.plot(preds[0])

# %%
plt.plot(preds[0])

# %%
plt.plot(preds[0])

# %%
plt.hist(preds[0])
# Out:
# (array([ 4.,  2.,  2.,  2.,  8.,  4.,  5.,  2.,  2.,  1.]),
#  array([-0.92939693, -0.74439234, -0.55938776, -0.37438317, -0.18937858,
#         -0.004374  ,  0.18063059,  0.36563517,  0.55063976,  0.73564435,
#          0.92064893]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(preds[0])
# Out:
# (array([ 4.,  2.,  2.,  2.,  8.,  4.,  5.,  2.,  2.,  1.]),
#  array([-0.92939693, -0.74439234, -0.55938776, -0.37438317, -0.18937858,
#         -0.004374  ,  0.18063059,  0.36563517,  0.55063976,  0.73564435,
#          0.92064893]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(preds[0])
# Out:
# (array([ 4.,  2.,  2.,  2.,  8.,  4.,  5.,  2.,  2.,  1.]),
#  array([-0.92939693, -0.74439234, -0.55938776, -0.37438317, -0.18937858,
#         -0.004374  ,  0.18063059,  0.36563517,  0.55063976,  0.73564435,
#          0.92064893]),
#  <a list of 10 Patch objects>)

# %%
#. 2. Feature extraction
model = MusicTaggerCRNN(weights='msd', include_top=False)

audio_path = 'audio_file.mp3'
melgram = preprocess_input(audio_path)
melgrams = np.expand_dims(melgram, axis=0)

feats = model.predict(melgrams)
print('Features:')
print(feats[0, :10])
# print: ('Features:', [-0.19160545 0.94259131 -0.9991011 0.47644514 -0.19089699 0.99033844 0.1103896 -0.00340496 0.14823607 0.59856361])

# %%
msg = msgs[0]
# msg = np.divide(msg, 255)
print msg.shape
plt.figure(figsize=(10, 3))
plt.imshow(np.flipud(msg), aspect=4)
# Out:
# (96, 1876)
