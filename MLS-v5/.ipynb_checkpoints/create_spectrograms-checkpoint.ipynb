# %% [markdown]
# ** Convert waveforms into Mel-scaled power spectrograms **

# %%
import os
import re
import time
import librosa
import numpy as np
from scipy import io
from tqdm import tqdm
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
INPUT_DIRS = [
    '/datasets/kaggle/mls/train_1',
    '/datasets/kaggle/mls/train_2',
    '/datasets/kaggle/mls/train_3',
    '/datasets/kaggle/mls/new/test_1_new/',
    '/datasets/kaggle/mls/new/test_2_new/',
    '/datasets/kaggle/mls/new/test_3_new/'
]

OUTPUT_DIRS = {
    'msgs': 'out/msgs'
}

SAMPLING_RATE = 400
N_CHANNELS = 16
N_SAMPLES = 240000

N_FFT=512
N_MELS=1024
DESIRED_MSG_W = 2048
HOP_LEN = 1 + int(N_SAMPLES / (DESIRED_MSG_W - 1))

print 'Params:\n'
print 'DESIRED_MSG_W', DESIRED_MSG_W
print 'HOP_LEN', HOP_LEN
# Out:
# Params:
#
# DESIRED_MSG_W 2048
# HOP_LEN 118

# %%
# make sure output dirs exist
for v in OUTPUT_DIRS.values(): 
    if not os.path.isdir(v): 
        os.makedirs(v)

# %%
# list files in directories
def list_files(src_dirs):

    if not list == type(src_dirs): src_dirs = [src_dirs]
    
    f = []
    
    for d in src_dirs:
        df = []
        for (dirpath, dirnames, filenames) in os.walk(d):
            filenames = [dirpath + '/' + x for x in filenames]
            df.extend(filenames)
        f.extend(df)
    
    return f

# %%
def read_mat(f):
    mat = io.loadmat(f)
    
    sampling_rate = int(mat['dataStruct'][0, 0][1][0, 0])
    n_samples = int(mat['dataStruct'][0, 0][2][0, 0])
    ch_indexes = np.int8(mat['dataStruct'][0, 0][3][0])
    
    # make sure all files have the same format
    assert(sampling_rate == SAMPLING_RATE)
    assert(n_samples == N_SAMPLES)
    assert(len(ch_indexes) == N_CHANNELS)
    
    data = mat['dataStruct'][0, 0][0].T
    
    waves = np.zeros([len(ch_indexes), n_samples], dtype=np.float32)
    
    for i in range(len(ch_indexes)):
        waves[i] = data[ch_indexes[i] - 1]  
        
    return waves

# %%
# compute msg for a wave
def compute_msg(wave, \
                sr=SAMPLING_RATE, hop_length=HOP_LEN, \
                n_fft=N_FFT, n_mels=N_MELS, \
                desired_msg_w=DESIRED_MSG_W):
    
    # pad wave if neccessary to get the desired msg width
    desired_wave_len = hop_length * (desired_msg_w - 1)
    if desired_wave_len > len(wave):
        wave = np.pad(wave, (0, desired_wave_len - len(wave)), \
                      'constant', constant_values=(0))
    
    msg = librosa.feature.melspectrogram(y=wave, sr=sr, hop_length=hop_length, n_fft=n_fft, n_mels=n_mels)
    msg = librosa.logamplitude(msg ** 2, ref_power=1.)
    
    return msg

# %%
# process waveforms
for f in tqdm(list_files(INPUT_DIRS)):
    fid = re.findall(r'([\d_]+)\.mat$', f)[0]
    waves = read_mat(f)
    msgs = np.zeros([N_CHANNELS, N_MELS, DESIRED_MSG_W])
        
    for i in range(waves.shape[0]):
        msgs[i] = compute_msg(waves[i])
        
    msgs_f = OUTPUT_DIRS['msgs'] + '/' + fid + '.npy'
    np.save(msgs_f, np.divide(msgs, 255.).astype(np.float32))
# Out:
#   0%|          | 2/12168 [00:02<3:43:10,  1.10s/it]
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-20-4f0c81e5ee5e> in <module>()
#       6
#       7     for i in range(waves.shape[0]):
# ----> 8         msgs[i] = compute_msg(waves[i])
#       9
#      10     msgs_f = OUTPUT_DIRS['msgs'] + '/' + fid + '.npy'
#
# <ipython-input-18-e36c6462befb> in compute_msg(wave, sr, hop_length, n_fft, n_mels, desired_msg_w)
#       8
#       9     msg = librosa.feature.melspectrogram(y=wave, sr=sr, hop_length=hop_length, n_fft=n_fft, n_mels=n_mels)
# ---> 10     msg = librosa.logamplitude(msg ** 2, ref_power=1.)
#      11
#      12     return msg
#
# /usr/local/lib/python2.7/dist-packages/librosa/core/spectrum.pyc in logamplitude(S, ref_power, amin, top_db)
#     692         __ref = np.abs(ref_power)
#     693
# --> 694     log_spec = 10.0 * np.log10(np.maximum(amin, magnitude))
#     695     log_spec -= 10.0 * np.log10(np.maximum(amin, __ref))
#     696
#
# KeyboardInterrupt:

# %%
########################################

# %%
msgs.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-8-3e8a2060417d> in <module>()
# ----> 1 msgs.shape
#
# NameError: name 'msgs' is not defined

# %%
waves = read_mat('/datasets/kaggle/mls/train_2/2_102_1.mat')

msg = compute_msg(waves[0],n_mels=384)

print msg.shape
plt.figure(figsize=(10, 4))
plt.imshow(np.flipud(msg), aspect=1)
plt.savefig('msg.png')
# Out:
# (384, 2048)

# %%
waves = read_mat('/datasets/kaggle/mls/train_2/2_1020_0.mat')

msg = compute_msg(waves[0],n_mels=384)

print msg.shape
plt.figure(figsize=(10, 4))
plt.imshow(np.flipud(msg), aspect=1)
plt.savefig('msg.png')
# Out:
# (384, 2048)

# %%
msg = msgs[0]
# msg = np.divide(msg, 255)
print msg.shape
plt.figure(figsize=(10, 3))
plt.imshow(np.flipud(msg), aspect=4)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-13-90fd66eee5b5> in <module>()
# ----> 1 msg = msgs[0]
#       2 # msg = np.divide(msg, 255)
#       3 print msg.shape
#       4 plt.figure(figsize=(10, 3))
#       5 plt.imshow(np.flipud(msg), aspect=4)
#
# NameError: name 'msgs' is not defined
