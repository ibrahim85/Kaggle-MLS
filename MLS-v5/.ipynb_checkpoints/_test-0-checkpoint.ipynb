# %%
import os
import re
import time
import numpy as np
from scipy import io
from tqdm import tqdm
from scipy import signal
import matplotlib.pyplot as plt
import librosa
# %matplotlib inline

# %%
INPUT_DIRS = [
    '/datasets/kaggle/mls/train_1',
    '/datasets/kaggle/mls/train_2',
    '/datasets/kaggle/mls/train_3',
    '/datasets/kaggle/mls/test_1',
    '/datasets/kaggle/mls/test_2',
    '/datasets/kaggle/mls/test_3'
]

OUTPUT_DIRS = {
    'waveforms': 'out/waveforms',
    'cache': 'out/'
}

N_SAMPLES = 240000
SAMPLING_RATE = 400
N_CHANNELS = 16

# %%
# make sure output dirs exist
for v in OUTPUT_DIRS.values(): 
    if not os.path.isdir(v): 
        os.makedirs(v)

# %%
# list files in directories
def list_files(src_dirs):

    if not list == type(src_dirs): src_dirs = [src_dirs]
    
    f = []
    
    for d in src_dirs:
        df = []
        for (dirpath, dirnames, filenames) in os.walk(d):
            filenames = [dirpath + '/' + x for x in filenames]
            df.extend(filenames)
        f.extend(df)
    
    return f

# %%
def read_mat(f):
    mat = io.loadmat(f)
    
    sampling_rate = int(mat['dataStruct'][0, 0][1][0, 0])
    n_samples = int(mat['dataStruct'][0, 0][2][0, 0])
    ch_indexes = np.int8(mat['dataStruct'][0, 0][3][0])
    
    # make sure all files have the same format
    assert(sampling_rate == SAMPLING_RATE)
    assert(n_samples == N_SAMPLES)
    assert(len(ch_indexes) == N_CHANNELS)
    
    data = mat['dataStruct'][0, 0][0].T
    
    waves = np.zeros([len(ch_indexes), n_samples], dtype=np.float32)
    
    for i in range(len(ch_indexes)):
        waves[i] = data[ch_indexes[i] - 1]  
        
    return waves

# %%
# process waveforms
for f in list_files(INPUT_DIRS):
    fid = re.findall(r'([\d_]+)\.mat$', f)[0]
    waves = read_mat(f)
    print f, fid
    break
# Out:
# /datasets/kaggle/mls/train_1/1_167_0.mat 1_167_0

# %%
ww = np.random.random([2,240000]).astype(np.float32)
plt.figure(figsize=(25, 2))
librosa.display.specshow(ww, sr=400, hop_length=1024)

# %%
plt.figure(figsize=(25, 2))
librosa.display.specshow(ww, sr=4000, hop_length=2048)

# %%
d, s = librosa.load(librosa.util.example_audio_file())

# %%
plt.plot(d[100000:101000])

# %%
plt.figure(figsize=(12, 3))
librosa.display.specshow(d.reshape(1,-1), s, hop_length=512)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-76-8601b740768b> in <module>()
#       1 plt.figure(figsize=(12, 3))
# ----> 2 librosa.display.specshow(d.reshape(1,-1), s, hop_length=512, n_fft=128)
#
# /usr/local/lib/python2.7/dist-packages/librosa/display.pyc in specshow(data, sr, hop_length, x_axis, y_axis, n_xticks, n_yticks, fmin, fmax, bins_per_octave, tmin, tmax, freq_fmt, time_fmt, **kwargs)
#     681     kwargs.setdefault('cmap', cmap(data))
#     682
# --> 683     axes = plt.imshow(data, **kwargs)
#     684
#     685     all_params = dict(kwargs=kwargs,
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4918         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    4919                               filternorm=filternorm, filterrad=filterrad,
# -> 4920                               resample=resample, **kwargs)
#    4921
#    4922         im.set_data(X)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     595                                 filterrad=filterrad,
#     596                                 resample=resample,
# --> 597                                 **kwargs
#     598                                 )
#     599
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     128         self._image_skew_coordinate = None
#     129
# --> 130         self.update(kwargs)
#     131
#     132     def __getstate__(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in update(self, props)
#     857                 func = getattr(self, 'set_' + k, None)
#     858                 if func is None or not six.callable(func):
# --> 859                     raise AttributeError('Unknown property %s' % k)
#     860                 func(v)
#     861             changed = True
#
# AttributeError: Unknown property n_fft

# %%
msg = librosa.feature.melspectrogram(y=d, sr=s, hop_length=1024)

# %%
msg.shape
# Out:
# (128, 1324)
